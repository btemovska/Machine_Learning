# %% [markdown]
# ### Decision Tree Classifier

# %% [markdown]
# #### Import library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Import dataset

# %%
#hearing tests
df = pd.read_csv('hearing_test.csv')
df
# Out:
#        age  physical_score  test_result
# 0     33.0            40.7            1
# 1     50.0            37.2            1
# 2     52.0            24.7            0
# 3     56.0            31.0            0
# 4     35.0            42.9            1
# ...    ...             ...          ...
# 4995  73.0             3.9            0
# 4996  57.0            33.9            1
# 4997  49.0            34.5            1
# 4998  38.0            46.4            1
# 4999  48.0            38.5            1
#
# [5000 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# age               0
# physical_score    0
# test_result       0
# dtype: int64

# %%
sns.pairplot(df, hue='test_result')  #the nice separation between the test results should be give us a good prediction

# %% [markdown]
# #### Separate X features & y labels

# %%
X = df.drop('test_result', axis=1)
y = df['test_result']

# %% [markdown]
# #### Split Training/Test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %% [markdown]
# #### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Train the model

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier() 
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# #### Test the model

# %%
y_pred = model.predict(X_test)
new_df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})
new_df.sample(5)
# Out:
#       y_test  y_pred
# 3711       1       0
# 3808       1       1
# 2674       1       1
# 3475       1       1
# 214        1       1

# %% [markdown]
# #### Evaluate the model

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score

#model.coef_  #not available for Decision Tree

print(f'Accuracy Score: {accuracy_score(y_test, y_pred)}')
print(f"Precision Score: {precision_score(y_test, y_pred, average='weighted')}")
print(f"Recall Score: {recall_score(y_test, y_pred, average='weighted')}")
print(f"F1 Score: {f1_score(y_test, y_pred, average='weighted')}")
# Out:
# Accuracy Score: 0.896
# Precision Score: 0.8965033924712269
# Recall Score: 0.896
# F1 Score: 0.896192349726776

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(model, X_test, y_test).figure_.set_size_inches(4, 2)
# Out:
# C:\Users\btemo\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[169,  24],
#        [ 28, 279]], dtype=int64)

# %%
report = classification_report(y_test, y_pred, output_dict=True)
report = pd.DataFrame(report).transpose()
report # this breaks down the metrics by class
# Out:
#               precision    recall  f1-score  support
# 0              0.857868  0.875648  0.866667  193.000
# 1              0.920792  0.908795  0.914754  307.000
# accuracy       0.896000  0.896000  0.896000    0.896
# macro avg      0.889330  0.892221  0.890710  500.000
# weighted avg   0.896503  0.896000  0.896192  500.000

# %% [markdown]
# #### What are the most important X features?

# %%
pd.DataFrame(index=X.columns, data=model.feature_importances_, 
             columns=['Feature Importance']).sort_values('Feature Importance')
#physical_score is the most important feature
# Out:
#                 Feature Importance
# age                        0.11945
# physical_score             0.88055

# %%
from sklearn.tree import plot_tree
plot_tree(model, feature_names=X.columns, filled=True);
plt.figure(figsize=(12,12), dpi=300)
plt.show()

#note it started with the most important feature

# %% [markdown]
# #### Visualize

# %%
plt.figure(figsize=(8, 4))

sns.kdeplot(y_test, label='Actual', shade=True)
sns.kdeplot(y_pred, label='Predicted', shade=True)

plt.title('Actual and Predicted values')
plt.xlabel('Class')
plt.ylabel('Density/Frequency')
plt.legend()
plt.show()

# y_test & y_pred largely overlap, thus the predictions are closely aligned with the actual values.

# %%
# Combine y_test and y_pred into a single DataFrame
comparison_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# Plot the counts of each class
plt.figure(figsize=(8, 2))
plot = sns.countplot(y='variable', hue='value', data=pd.melt(comparison_df))

# Add counts on top of the bars
for p in plot.patches:
    plot.annotate(format(p.get_width(), '.0f'), 
                  (p.get_width(), p.get_y() + p.get_height() / 2.), 
                  ha = 'center', va = 'center', 
                  xytext = (9, 0), 
                  textcoords = 'offset points')

plt.legend(title='Value', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.7)
plt.title('Count of Actual and Predicted Classes')
plt.ylabel('Class')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Predict future patient

# %%
model.predict(scaler.transform([[33, 40]]))
#if patient is age 33 and has physical score of 40, then they will pass the hearing test
# Out:
# C:\Users\btemo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
